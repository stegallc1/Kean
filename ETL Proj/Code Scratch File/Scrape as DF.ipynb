# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
import io
from IPython.display import display_json
import certifi
import urllib3
import html5lib
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from tabulate import tabulate

# %%
URL = "https://www.ttilgb.com/uiAgs03Action/openScreen.do"
res = requests.get(URL, 'lxml', verify=False)

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
table = soup.find_all('tr')[0]

# %%
df = pd.read_html(str(table))

# %%
df
# Out:
# [                                                    0   \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  MSC
#  ..                                                 ...
#  99                                                 NaN
#  100                                Thursday – May 28th
#  101         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  102         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  103  Gate Schedule  Priority Message TTI EMPTY RECE...
#
#                                            1   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                           TRANSACTION TYPE
#  2                           TRANSACTION TYPE
#  3                           TRANSACTION TYPE
#  4                                        20'
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            2   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            3   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            4   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            5   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            6   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            7   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            8   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/25/2020
#  2                                     Monday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            9          10         11         12  \
#  0    TTI EMPTY RECEIVING - Subject to Change        NaN        NaN        NaN
#  1                                  5/25/2020  5/26/2020  5/26/2020  5/27/2020
#  2                                     Monday    Tuesday    Tuesday  Wednesday
#  3                                        2nd        1st        2nd        1st
#  4                                        NaN     SINGLE     SINGLE     SINGLE
#  ..                                       ...        ...        ...        ...
#  99                                       NaN        NaN        NaN        NaN
#  100                                      NaN        NaN        NaN        NaN
#  101                                      NaN        NaN        NaN        NaN
#  102                                      NaN        NaN        NaN        NaN
#  103                                      NaN        NaN        NaN        NaN
#
#              13   14   15
#  0          NaN  NaN  NaN
#  1    5/27/2020  NaN  NaN
#  2    Wednesday  NaN  NaN
#  3          2nd  NaN  NaN
#  4       SINGLE  20'  MSC
#  ..         ...  ...  ...
#  99         NaN  NaN  NaN
#  100        NaN  NaN  NaN
#  101        NaN  NaN  NaN
#  102        NaN  NaN  NaN
#  103        NaN  NaN  NaN
#
#  [104 rows x 16 columns],
#                                                      0   \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  MSC
#  ..                                                 ...
#  99                                                 NaN
#  100                                Thursday – May 28th
#  101         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  102         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  103  Gate Schedule  Priority Message TTI EMPTY RECE...
#
#                                            1   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                           TRANSACTION TYPE
#  2                           TRANSACTION TYPE
#  3                           TRANSACTION TYPE
#  4                                        20'
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            2   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            3   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            4   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            5   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            6   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            7   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            8   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/25/2020
#  2                                     Monday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            9          10         11         12  \
#  0    TTI EMPTY RECEIVING - Subject to Change        NaN        NaN        NaN
#  1                                  5/25/2020  5/26/2020  5/26/2020  5/27/2020
#  2                                     Monday    Tuesday    Tuesday  Wednesday
#  3                                        2nd        1st        2nd        1st
#  4                                        NaN     SINGLE     SINGLE     SINGLE
#  ..                                       ...        ...        ...        ...
#  99                                       NaN        NaN        NaN        NaN
#  100                                      NaN        NaN        NaN        NaN
#  101                                      NaN        NaN        NaN        NaN
#  102                                      NaN        NaN        NaN        NaN
#  103                                      NaN        NaN        NaN        NaN
#
#              13   14   15
#  0          NaN  NaN  NaN
#  1    5/27/2020  NaN  NaN
#  2    Wednesday  NaN  NaN
#  3          2nd  NaN  NaN
#  4       SINGLE  20'  MSC
#  ..         ...  ...  ...
#  99         NaN  NaN  NaN
#  100        NaN  NaN  NaN
#  101        NaN  NaN  NaN
#  102        NaN  NaN  NaN
#  103        NaN  NaN  NaN
#
#  [104 rows x 16 columns],
#      0              1
#  0 NaN  Gate Schedule,
#                                                      0   \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  MSC
#  ..                                                 ...
#  99                                                 NaN
#  100                                Thursday – May 28th
#  101         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  102         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  103  Priority Message TTI EMPTY RECEIVING - Subject...
#
#                                            1   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                           TRANSACTION TYPE
#  2                           TRANSACTION TYPE
#  3                           TRANSACTION TYPE
#  4                                        20'
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            2   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            3   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/22/2020
#  2                                     Friday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            4   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        1st
#  4                                     SINGLE
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            5   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/23/2020
#  2                                   Saturday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            6   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            7   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/24/2020
#  2                                     Sunday
#  3                                        2nd
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            8   \
#  0    TTI EMPTY RECEIVING - Subject to Change
#  1                                  5/25/2020
#  2                                     Monday
#  3                                        1st
#  4                                        NaN
#  ..                                       ...
#  99                                       NaN
#  100                                      NaN
#  101                                      NaN
#  102                                      NaN
#  103                                      NaN
#
#                                            9          10         11         12  \
#  0    TTI EMPTY RECEIVING - Subject to Change        NaN        NaN        NaN
#  1                                  5/25/2020  5/26/2020  5/26/2020  5/27/2020
#  2                                     Monday    Tuesday    Tuesday  Wednesday
#  3                                        2nd        1st        2nd        1st
#  4                                        NaN     SINGLE     SINGLE     SINGLE
#  ..                                       ...        ...        ...        ...
#  99                                       NaN        NaN        NaN        NaN
#  100                                      NaN        NaN        NaN        NaN
#  101                                      NaN        NaN        NaN        NaN
#  102                                      NaN        NaN        NaN        NaN
#  103                                      NaN        NaN        NaN        NaN
#
#              13   14   15
#  0          NaN  NaN  NaN
#  1    5/27/2020  NaN  NaN
#  2    Wednesday  NaN  NaN
#  3          2nd  NaN  NaN
#  4       SINGLE  20'  MSC
#  ..         ...  ...  ...
#  99         NaN  NaN  NaN
#  100        NaN  NaN  NaN
#  101        NaN  NaN  NaN
#  102        NaN  NaN  NaN
#  103        NaN  NaN  NaN
#
#  [104 rows x 16 columns],
#                    0
#  0  Priority Message,
#                                                     0   \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 MSC
#  ..                                                ...
#  68                                                NaN
#  69                                                NaN
#  70                                                NaN
#  71                                                NaN
#  72  TTI EMPTY RECEIVING - Subject to Change TRANSA...
#
#                                           1   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                          TRANSACTION TYPE
#  2                          TRANSACTION TYPE
#  3                          TRANSACTION TYPE
#  4                                       20'
#  ..                                      ...
#  68                                      45'
#  69                                  JB HUNT
#  70                                SCHNEIDER
#  71             GENERAL TERMINAL INFORMATION
#  72                                      NaN
#
#                                           2   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/22/2020
#  2                                    Friday
#  3                                       1st
#  4                                    SINGLE
#  ..                                      ...
#  68                                        X
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#  72                                      NaN
#
#                                           3   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/22/2020
#  2                                    Friday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  68                                      NaN
#  69                                        X
#  70                                        X
#  71             GENERAL TERMINAL INFORMATION
#  72                                      NaN
#
#                                           4   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/23/2020
#  2                                  Saturday
#  3                                       1st
#  4                                    SINGLE
#  ..                                      ...
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#  72                                      NaN
#
#                                           5   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/23/2020
#  2                                  Saturday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#  72                                      NaN
#
#                                           6   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/24/2020
#  2                                    Sunday
#  3                                       1st
#  4                                       NaN
#  ..                                      ...
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71                                      NaN
#  72                                      NaN
#
#                                           7   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/24/2020
#  2                                    Sunday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  68                                   SINGLE
#  69                                     DUAL
#  70                                       NO
#  71                                      NaN
#  72                                      NaN
#
#                                           8   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/25/2020
#  2                                    Monday
#  3                                       1st
#  4                                       NaN
#  ..                                      ...
#  68              EMPTY IN AND DUALS ACCEPTED
#  69     EMPTY CONTAINER IN AND CONTAINER OUT
#  70           NOT ACCEPTING TRANSACTION TYPE
#  71                                      NaN
#  72                                      NaN
#
#                                           9   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/25/2020
#  2                                    Monday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  68              EMPTY IN AND DUALS ACCEPTED
#  69     EMPTY CONTAINER IN AND CONTAINER OUT
#  70           NOT ACCEPTING TRANSACTION TYPE
#  71                                      NaN
#  72                                      NaN
#
#                                        10  \
#  0                                    NaN
#  1                              5/26/2020
#  2                                Tuesday
#  3                                    1st
#  4                                 SINGLE
#  ..                                   ...
#  68           EMPTY IN AND DUALS ACCEPTED
#  69  EMPTY CONTAINER IN AND CONTAINER OUT
#  70        NOT ACCEPTING TRANSACTION TYPE
#  71                                   NaN
#  72                                   NaN
#
#                                        11         12         13   14   15
#  0                                    NaN        NaN        NaN  NaN  NaN
#  1                              5/26/2020  5/27/2020  5/27/2020  NaN  NaN
#  2                                Tuesday  Wednesday  Wednesday  NaN  NaN
#  3                                    2nd        1st        2nd  NaN  NaN
#  4                                 SINGLE     SINGLE     SINGLE  20'  MSC
#  ..                                   ...        ...        ...  ...  ...
#  68           EMPTY IN AND DUALS ACCEPTED        NaN        NaN  NaN  NaN
#  69  EMPTY CONTAINER IN AND CONTAINER OUT        NaN        NaN  NaN  NaN
#  70        NOT ACCEPTING TRANSACTION TYPE        NaN        NaN  NaN  NaN
#  71                                   NaN        NaN        NaN  NaN  NaN
#  72                                   NaN        NaN        NaN  NaN  NaN
#
#  [73 rows x 16 columns],
#       0                                        1   \
#  0   NaN  TTI EMPTY RECEIVING - Subject to Change
#  1   NaN                         TRANSACTION TYPE
#  2   NaN                         TRANSACTION TYPE
#  3   NaN                         TRANSACTION TYPE
#  4   MSC                                      20'
#  ..  ...                                      ...
#  67  NaN                                      40'
#  68  NaN                                      45'
#  69  NaN                                  JB HUNT
#  70  NaN                                SCHNEIDER
#  71  NaN             GENERAL TERMINAL INFORMATION
#
#                                           2   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/22/2020
#  2                                    Friday
#  3                                       1st
#  4                                    SINGLE
#  ..                                      ...
#  67                                        X
#  68                                        X
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#
#                                           3   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/22/2020
#  2                                    Friday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  67                                      NaN
#  68                                      NaN
#  69                                        X
#  70                                        X
#  71             GENERAL TERMINAL INFORMATION
#
#                                           4   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/23/2020
#  2                                  Saturday
#  3                                       1st
#  4                                    SINGLE
#  ..                                      ...
#  67                                      NaN
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#
#                                           5   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/23/2020
#  2                                  Saturday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  67                                      NaN
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71             GENERAL TERMINAL INFORMATION
#
#                                           6   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/24/2020
#  2                                    Sunday
#  3                                       1st
#  4                                       NaN
#  ..                                      ...
#  67                                      NaN
#  68                                      NaN
#  69                                      NaN
#  70                                      NaN
#  71                                      NaN
#
#                                           7   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/24/2020
#  2                                    Sunday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  67                                   LEGEND
#  68                                   SINGLE
#  69                                     DUAL
#  70                                       NO
#  71                                      NaN
#
#                                           8   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/25/2020
#  2                                    Monday
#  3                                       1st
#  4                                       NaN
#  ..                                      ...
#  67                                   LEGEND
#  68              EMPTY IN AND DUALS ACCEPTED
#  69     EMPTY CONTAINER IN AND CONTAINER OUT
#  70           NOT ACCEPTING TRANSACTION TYPE
#  71                                      NaN
#
#                                           9   \
#  0   TTI EMPTY RECEIVING - Subject to Change
#  1                                 5/25/2020
#  2                                    Monday
#  3                                       2nd
#  4                                       NaN
#  ..                                      ...
#  67                                   LEGEND
#  68              EMPTY IN AND DUALS ACCEPTED
#  69     EMPTY CONTAINER IN AND CONTAINER OUT
#  70           NOT ACCEPTING TRANSACTION TYPE
#  71                                      NaN
#
#                                        10  \
#  0                                    NaN
#  1                              5/26/2020
#  2                                Tuesday
#  3                                    1st
#  4                                 SINGLE
#  ..                                   ...
#  67                                LEGEND
#  68           EMPTY IN AND DUALS ACCEPTED
#  69  EMPTY CONTAINER IN AND CONTAINER OUT
#  70        NOT ACCEPTING TRANSACTION TYPE
#  71                                   NaN
#
#                                        11         12         13   14   15
#  0                                    NaN        NaN        NaN  NaN  NaN
#  1                              5/26/2020  5/27/2020  5/27/2020  NaN  NaN
#  2                                Tuesday  Wednesday  Wednesday  NaN  NaN
#  3                                    2nd        1st        2nd  NaN  NaN
#  4                                 SINGLE     SINGLE     SINGLE  20'  MSC
#  ..                                   ...        ...        ...  ...  ...
#  67                                LEGEND        NaN        NaN  NaN  NaN
#  68           EMPTY IN AND DUALS ACCEPTED        NaN        NaN  NaN  NaN
#  69  EMPTY CONTAINER IN AND CONTAINER OUT        NaN        NaN  NaN  NaN
#  70        NOT ACCEPTING TRANSACTION TYPE        NaN        NaN  NaN  NaN
#  71                                   NaN        NaN        NaN  NaN  NaN
#
#  [72 rows x 16 columns],
#                        0
#  0  Weekly Gate Schedule,
#                                                      0
#  0                                 Thursday – May 21st
#  1          0700 – 1759 FULL SERVICE GATE (Front Gate)
#  2           1900 – 0330 FULL SERVICE GATE (Front Gate
#  3                                    Friday– May 22nd
#  4     0700 – 1759 FULL SERVICE GATE (Front Gate Only)
#  5                                  1900 – 0330 CLOSED
#  6                                 Saturday – May 23rd
#  7     0700 – 1759 FULL SERVICE GATE (Front Gate Only)
#  8                                  1900 – 0330 CLOSED
#  9                                   Sunday – May 24th
#  10                                 0700 – 1759 CLOSED
#  11                                 1900 – 0330 CLOSED
#  12                    Monday- May 25th (Memorial Day)
#  13                                 0700 – 1759 CLOSED
#  14                                 1900 – 0330 CLOSED
#  15                                 Tuesday – May 26th
#  16         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  17         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  18                               Wednesday – May 27th
#  19         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  20         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  21                                Thursday – May 28th
#  22         0700 – 1759 FULL SERVICE GATE (Front Gate)
#  23         1900 – 0330 FULL SERVICE GATE (Front Gate)
#  24  Thursday – May 21st 0700 – 1759 FULL SERVICE G...,
#                                                    0
#  0                               Thursday – May 21st
#  1        0700 – 1759 FULL SERVICE GATE (Front Gate)
#  2         1900 – 0330 FULL SERVICE GATE (Front Gate
#  3                                  Friday– May 22nd
#  4   0700 – 1759 FULL SERVICE GATE (Front Gate Only)
#  5                                1900 – 0330 CLOSED
#  6                               Saturday – May 23rd
#  7   0700 – 1759 FULL SERVICE GATE (Front Gate Only)
#  8                                1900 – 0330 CLOSED
#  9                                 Sunday – May 24th
#  10                               0700 – 1759 CLOSED
#  11                               1900 – 0330 CLOSED
#  12                  Monday- May 25th (Memorial Day)
#  13                               0700 – 1759 CLOSED
#  14                               1900 – 0330 CLOSED
#  15                               Tuesday – May 26th
#  16       0700 – 1759 FULL SERVICE GATE (Front Gate)
#  17       1900 – 0330 FULL SERVICE GATE (Front Gate)
#  18                             Wednesday – May 27th
#  19       0700 – 1759 FULL SERVICE GATE (Front Gate)
#  20       1900 – 0330 FULL SERVICE GATE (Front Gate)
#  21                              Thursday – May 28th
#  22       0700 – 1759 FULL SERVICE GATE (Front Gate)
#  23       1900 – 0330 FULL SERVICE GATE (Front Gate)]
