# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import certifi
import urllib3
from urllib.request import urlopen
import os
import html5lib
import copy
import math
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
from itertools import product

# %%
URL = "https://www.ttilgb.com/uiAgs03Action/openScreen.do"
res = requests.get(URL, 'lxml', verify=False)
soup = BeautifulSoup(res.content, 'lxml')

# %%
tables = soup.find_all('table')

# %%
for table in tables:
    print(table.prettify())
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tr>
#   <td valign="top">
#    <table border="0" cellpadding="0" cellspacing="0" class="search" style="width:100%">
#     <tr>
#      <td>
#       <!-- title (s) -->
#       <table border="0" cellpadding="0" cellspacing="0" class="title">
#        <tr height="35">
#         <td class="title" width="18">
#          <img alt="" border="0" height="14" src="/resource/img/icon_title_dot.gif" width="13"/>
#         </td>
#         <td class="title">
#          Gate Schedule
#         </td>
#        </tr>
#       </table>
#       <!-- title (e) -->
#       <table>
#        <tr>
#         <td height="5">
#         </td>
#        </tr>
#       </table>
#       <!-- : contents area (S) -->
#       <table style="width:100%;">
#        <tr>
#         <td class="bg">
#          <table border="0" style="width:100%;">
#           <tr>
#            <td class="h25">
# ...

# %%
table = soup.find('table', {'class': 'h23'})
rows = soup.find_all('tr')

# %%
print(rows)
# Out:
# [<tr>
# <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" class="search" style="width:100%">
# <tr>
# <td>
# <!-- title (s) -->
# <table border="0" cellpadding="0" cellspacing="0" class="title">
# <tr height="35">
# <td class="title" width="18"><img alt="" border="0" height="14" src="/resource/img/icon_title_dot.gif" width="13"/></td>
# <td class="title">Gate Schedule</td>
# </tr>
# </table>
# <!-- title (e) -->
# <table><tr><td height="5"></td></tr></table>
# <!-- : contents area (S) -->
# <table style="width:100%;">
# <tr>
# <td class="bg">
# <table border="0" style="width:100%;">
# <tr>
# <td class="h25"><img align="absmiddle" alt="" border="0" height="17" src="/resource/img/img_topmenu_sub_on_arrow.gif" width="12"/> Priority Message</td>
# </tr>
# </table>
# <table width="100%">
# <tr>
# <td class="h23" style="width:100%;height:150;" valign="middle">
# <p>
# ...

# %%
data_content = []
for row in rows:
    cells = row.find_all('td')
    if len(cells) > 1:
        print(cells[1].get_text())
        if (len(additional_details) == 4):
        country_link = cells[1].find('a')
        print(country_link.get('href'))

# %%
first_table.to_excel(r"C:\Users\CodyS\Desktop\ETL-Project\data.xlsx", header = False, index = False)
