# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
import io
from IPython.display import display_json
import certifi
import urllib3
import html5lib
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from tabulate import tabulate

# %%
URL = "https://www.ttilgb.com/uiAgs03Action/openScreen.do"
res = requests.get(URL, 'lxml', verify=False)

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
table = soup.find_all('tr')[0]

# %%
df = pd.read_html(str(table))

# %%
print(df[0].to_json(orient='records'))
# Out:
# [{"0":null,"1":"TTI EMPTY RECEIVING - Subject to Change","2":"TTI EMPTY RECEIVING - Subject to Change","3":"TTI EMPTY RECEIVING - Subject to Change","4":"TTI EMPTY RECEIVING - Subject to Change","5":"TTI EMPTY RECEIVING - Subject to Change","6":"TTI EMPTY RECEIVING - Subject to Change","7":"TTI EMPTY RECEIVING - Subject to Change","8":"TTI EMPTY RECEIVING - Subject to Change","9":"TTI EMPTY RECEIVING - Subject to Change","10":null,"11":null,"12":null,"13":null,"14":null,"15":null},{"0":null,"1":"TRANSACTION TYPE","2":"5\/22\/2020","3":"5\/22\/2020","4":"5\/23\/2020","5":"5\/23\/2020","6":"5\/24\/2020","7":"5\/24\/2020","8":"5\/25\/2020","9":"5\/25\/2020","10":"5\/26\/2020","11":"5\/26\/2020","12":"5\/27\/2020","13":"5\/27\/2020","14":null,"15":null},{"0":null,"1":"TRANSACTION TYPE","2":"Friday","3":"Friday","4":"Saturday","5":"Saturday","6":"Sunday","7":"Sunday","8":"Monday","9":"Monday","10":"Tuesday","11":"Tuesday","12":"Wednesday","13":"Wednesday","14":null,"15":null},{"0":null,"1":"TRANSACTION TYPE","2":"1st","3":"2nd","4":"1st","5":"2nd","6":"1st","7":"2nd","8":"1st","9":"2nd","10":"1st","11":"2nd","12":"1st","13":"2nd","14":null,"15":null},{"0":"MSC","1":"20'","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"20'","15":"MSC"},{"0":"MSC","1":"40'","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"40'","15":"MSC"},{"0":"MSC","1":"40HC","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"40HC","15":"MSC"},{"0":"MSC","1":"45","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"45","15":"MSC"},{"0":"MSC","1":"Reefer","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Reefer","15":"MSC"},{"0":"MSC","1":"Special Eq","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Special Eq","15":"MSC"},{"0":"MSC","1":"Flat Racks","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Flat Racks","15":"MSC"},{"0":"HMM","1":"20'","2":"DUAL","3":null,"4":"DUAL","5":null,"6":null,"7":null,"8":null,"9":null,"10":"DUAL","11":"DUAL","12":"DUAL","13":"DUAL","14":"20'","15":"HMM"},{"0":"HMM","1":"40'","2":"DUAL","3":null,"4":"DUAL","5":null,"6":null,"7":null,"8":null,"9":null,"10":"DUAL","11":"DUAL","12":"DUAL","13":"DUAL","14":"40'","15":"HMM"},{"0":"HMM","1":"40HC","2":"DUAL","3":null,"4":"DUAL","5":null,"6":null,"7":null,"8":null,"9":null,"10":"DUAL","11":"DUAL","12":"DUAL","13":"DUAL","14":"40HC","15":"HMM"},{"0":"HMM","1":"45","2":"DUAL","3":null,"4":"DUAL","5":null,"6":null,"7":null,"8":null,"9":null,"10":"DUAL","11":"DUAL","12":"DUAL","13":"DUAL","14":"45","15":"HMM"},{"0":"HMM","1":"Reefer","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Reefer","15":"HMM"},{"0":"HMM","1":"Special Eq","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Special Eq","15":"HMM"},{"0":"HMM","1":"Flat Racks","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"Flat Racks","15":"HMM"},{"0":"MAE","1":"20'","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE","11":"SINGLE","12":"SINGLE","13":"SINGLE","14":"20'","15":"MAE"},{"0":"MAE","1":"40'","2":"SINGLE","3":null,"4":"SINGLE","5":null,"6":null,"7":null,"8":null,"9":null,"10":"SINGLE"," ...
