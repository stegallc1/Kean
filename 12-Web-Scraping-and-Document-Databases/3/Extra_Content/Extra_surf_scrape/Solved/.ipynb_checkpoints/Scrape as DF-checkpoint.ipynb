# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
import io
from IPython.display import display_json
import certifi
import urllib3
import html5lib
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
URL = "https://www.ttilgb.com/uiAgs03Action/openScreen.do"
content = requests.get(URL, verify=False)

# %%
soup = BeautifulSoup(content.text, 'html.parser')

# %%
row = soup.find('tbody') # Extract and return first occurrence of tr
print(row)            # Print row with HTML formatting
# Out:
# <tbody>
# <tr height="29" style="height: 21.75pt">
# <td class="xl65" height="29" style="border-top: #f0f0f0; height: 21.75pt; border-right: #f0f0f0; width: 48pt; border-bottom: #f0f0f0; border-left: #f0f0f0; background-color: transparent" width="64"></td>
# <td class="xl145" colspan="9" style="border-top: windowtext 1pt solid; border-right: black 0.5pt solid; width: 507pt; border-bottom: windowtext 1pt solid; border-left: windowtext 1pt solid; background-color: #d9d9d9" width="676"><font face="Calibri" size="5"><strong>TTI EMPTY RECEIVING - Subject to Change</strong></font></td>
# <td style="border-top: #f0f0f0; border-right: #f0f0f0; width: 51pt; border-bottom: #f0f0f0; border-left: #f0f0f0; background-color: transparent" width="68"></td>
# <td style="border-top: #f0f0f0; border-right: #f0f0f0; width: 51pt; border-bottom: #f0f0f0; border-left: #f0f0f0; background-color: transparent" width="68"></td>
# ...

# %%
pd.read_clipboard(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-753b6394c3b5> in <module>
# ----> 1 pd.read_clipboard(row)
#
# ~\Anaconda3\lib\site-packages\pandas\io\clipboards.py in read_clipboard(sep, **kwargs)
#      71         )
#      72
# ---> 73     return read_csv(StringIO(text), sep=sep, **kwargs)
#      74
#      75
#
# ...
